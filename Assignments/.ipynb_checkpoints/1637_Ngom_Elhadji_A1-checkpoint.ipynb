# %% [markdown]
# <h1>Assignment 1</h1>
#
# <p>In this first assignment we are focusing on a classification problem.<br>
# Our goal will be to use both the <b>K-Nearest Neighbors</b> and the <b>Decision Tree</b> techniques and try to compare the predictive models obtained.</p>
#
# <h3>The Dataset</h3>
# <p>For this assignment we will be using the sonar_train.csv data set</p>
# <p>This data set contains signals obtained from a variety of different aspect angles, spanning 90 degrees for mines and 180 degrees for rocks. Each sample is a set of 60 numbers in the range 0.0 to 1.0, where each number represents the energy within a particular frequency band (integrated over a certain period of time). The output target contains the letter R if the object is a rock and M if it is a mine (metal cylinder).</p>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
#Opening the sonar_train.csv file
data = pd.read_csv('sonar.csv','r')

###Display informations and the different column/features names

# %%
data
# Out:
#    Band1,Band2,Band3,Band4,Band5,Band6,Band7,Band8,Band9,Band10,Band11,Band12,Band13,Band14,Band15,Band16,Band17,Band18,Band19,Band20,Band21,Band22,Band23,Band24,Band25,Band26,Band27,Band28,Band29,Band30,Band31,Band32,Band33,Band34,Band35,Band36,Band37,Band38,Band39,Band40,Band41,Band42,Band43,Band44,Band45,Band46,Band47,Band48,Band49,Band50,Band51,Band52,Band53,Band54,Band55,Band56,Band57,Band58,Band59,Band60,Type
# 0   0.02,0.037,0.043,0.021,0.095,0.099,0.154,0.16,...
# 1   0.045,0.052,0.084,0.069,0.118,0.258,0.216,0.34...
# 2   0.026,0.058,0.11,0.108,0.097,0.228,0.243,0.377...
# 3   0.01,0.017,0.062,0.02,0.02,0.037,0.11,0.128,0....
# 4   0.076,0.067,0.048,0.039,0.059,0.065,0.121,0.24...
# 5   0.029,0.045,0.028,0.017,0.038,0.099,0.12,0.183...
# 6   0.032,0.096,0.132,0.141,0.167,0.171,0.073,0.14...
# 7   0.052,0.055,0.084,0.032,0.116,0.092,0.103,0.06...
# 8   0.022,0.038,0.048,0.048,0.065,0.059,0.075,0.01...
# 9   0.016,0.017,0.035,0.0070,0.019,0.067,0.106,0.0...
# 10  0.0040,0.0060,0.015,0.034,0.031,0.028,0.04,0.0...
# 11  0.012,0.031,0.017,0.031,0.036,0.01,0.018,0.058...
# 12  0.0080,0.0090,0.0060,0.025,0.034,0.055,0.053,0...
# 13  0.0090,0.0060,0.025,0.049,0.12,0.159,0.139,0.0...
# 14  0.012,0.043,0.06,0.045,0.06,0.036,0.053,0.034,...
# 15  0.03,0.062,0.065,0.092,0.162,0.229,0.218,0.203...
# 16  0.035,0.012,0.019,0.047,0.074,0.118,0.168,0.15...
# 17  0.019,0.061,0.038,0.077,0.139,0.081,0.057,0.02...
# 18  0.027,0.0090,0.014,0.028,0.041,0.076,0.103,0.1...
# 19  0.013,0.015,0.064,0.173,0.256,0.256,0.295,0.41...
# 20  0.047,0.051,0.082,0.125,0.178,0.307,0.301,0.23...
# 21  0.066,0.058,0.084,0.037,0.046,0.077,0.077,0.11...
# 22  0.01,0.048,0.03,0.03,0.065,0.108,0.236,0.238,0...
# 23  0.012,0.015,0.014,0.0080,0.021,0.106,0.102,0.0...
# 24  0.029,0.064,0.039,0.017,0.048,0.082,0.099,0.03...
# 25  0.02,0.0030,0.014,0.0060,0.013,0.015,0.054,0.0...
# 26  0.015,0.032,0.06,0.105,0.116,0.173,0.168,0.112...
# 27  0.018,0.03,0.029,0.039,0.063,0.053,0.069,0.063...
# 28  0.01,0.028,0.019,0.037,0.042,0.02,0.031,0.065,...
# 29  0.019,0.031,0.02,0.062,0.0080,0.079,0.144,0.14...
# 30  0.024,0.022,0.032,0.057,0.033,0.051,0.09,0.071...
# 31  0.0080,0.015,0.029,0.043,0.095,0.075,0.041,0.0...
# 32  0.02,0.021,0.0060,0.019,0.032,0.057,0.1,0.067,...
# 33  0.044,0.048,0.0050,0.058,0.028,0.068,0.166,0.1...
# 34  0.031,0.049,0.069,0.083,0.0080,0.02,0.098,0.10...
# 35  0.021,0.013,0.053,0.057,0.065,0.143,0.134,0.20...
# 36  0.0090,0.017,0.04,0.036,0.068,0.071,0.102,0.08...
# 37  0.033,0.022,0.027,0.048,0.068,0.098,0.084,0.11...
# 38  0.012,0.0020,0.02,0.021,0.018,0.049,0.0030,0.0...
# 39  0.0090,0.021,0.021,0.05,0.066,0.08,0.097,0.087...
# 40  0.0070,0.023,0.051,0.044,0.025,0.064,0.042,0.1...
# 41  0.0090,0.018,0.0060,0.0060,0.026,0.046,0.047,0...
# 42  0.021,0.032,0.042,0.029,0.012,0.044,0.13,0.139...
# 43  0.0090,0.027,0.022,0.034,0.03,0.117,0.145,0.06...
# 44  0.026,0.045,0.039,0.024,0.132,0.132,0.161,0.21...
# 45  0.041,0.065,0.04,0.06,0.05,0.182,0.118,0.102,0...
# 46  0.031,0.034,0.02,0.089,0.157,0.175,0.092,0.135...
# 47  0.037,0.028,0.023,0.022,0.018,0.073,0.084,0.10...
# 48  0.019,0.0040,0.064,0.045,0.033,0.069,0.09,0.14...
# 49  0.012,0.058,0.062,0.06,0.14,0.188,0.142,0.145,...
# 50  0.035,0.071,0.033,0.027,0.037,0.079,0.108,0.06...
# 51  0.013,0.0070,0.031,0.031,0.0080,0.077,0.077,0....
# 52  0.0090,0.0050,0.0080,0.023,0.059,0.068,0.099,0...
# 53  0.029,0.038,0.026,0.0060,0.013,0.061,0.09,0.11...
# 54  0.013,0.0080,0.019,0.014,0.044,0.067,0.061,0.0...
# 55  0.02,0.012,0.012,0.024,0.055,0.021,0.089,0.084...
# 56  0.015,0.01,0.011,0.026,0.01,0.039,0.086,0.092,...
# 57  0.022,0.012,0.017,0.015,0.061,0.103,0.114,0.08...
# 58  0.022,0.0020,0.0080,0.01,0.044,0.091,0.089,0.0...
# 59  0.012,0.015,0.022,0.018,0.036,0.07,0.087,0.062...
#                                                   ...
#
# [208 rows x 1 columns]

# %% [markdown]
# <p>In this data set each band is a feature and the target is the type of the object</p>
# <h4> <u>QUESTION 1 :</u> How many samples and how many features do we have?</h4>
# <p><i>Type your answer here</i></p>

# %%
###using the train_test_split command split the data set in two : 'train' and 'test' with a ratio ~75%-25%
from sklearn.cross_validation import train_test_split

# %%
#The last column in our sets correspond to the target
###Count how many of 'R' and 'M' you have in total

# %%
#In order to make targets more easily usable we will replace 'R' and 'M' by 0 and 1 respectively.
###Do it for both sets using the command : .replace()

# %% [markdown]
# <h3>K-Nearest Neighbors approach</h3>
#
# <p>In this section we will apply the <b>K-Nearest Neighbors</b> technique to the data set</p>

# %%
from sklearn.neighbors import KNeighborsClassifier
###Fille the brackets to use the brute force approach and 7 neighbors
knn = KNeighborsClassifier()

### Train the Nearest Neighbor Classifier "knn" on the training set

# %% [markdown]
# <h4> <u>QUESTION 2 :</u> Which kind of impact has the choice of the algorithm?</h4>
# <p><i>Type your answer here</i></p>

# %%
#At any time it is possible to recall the parameters using :
knn.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': 1,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %% [markdown]
# <p>We now want to test the accuracy of the nearest neighbor classifier</p>

# %%
###Compute the target prediction for the elements of the test set and compare with their true value

# %%
#scikit actually includes an accuracy evaluation function :
###Compute the accuracy using knn.score()

# %% [markdown]
# <h4> <u>QUESTION 3 :</u> Is the accuracy acceptable?</h4>
# <p><i>Type your answer here</i></p>
#
# <p>In the following cell repeat the training and the test steps with different knn parameters and try to find a good combination.</p>

# %% [markdown]
# <h4> <u>QUESTION 4 :</u> What is the best accuracy you get? What can you conclude?</h4>
# <p><i>Type your answer here</i></p>

# %% [markdown]
# <h3>Decision Tree</h3>
#
# <p>Using the same sets we now investigate the efficiency of a <b>decision tree classifier<b> </p>

# %%
from sklearn import tree
###
dtr = tree.DecisionTreeClassifier()

###train the decision tree classifier "dtr"

# %%
#Same as previously we can display some informations
dtr.get_params()
# Out:
# {'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': False,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# <h4> <u>QUESTION 5 :</u> From the list above, give the keywords influencing the test performed at a decison node?</h4>
# <p><i>Type your answer here</i></p>
#
# <p>In the follwing, using the work done previously test the accuracy of the decision tree classifier.</p>

# %% [markdown]
# <p>Hereafter, using different parameters for our decision tree, try to improve the accuracy</p>
#
# <h4> <u>QUESTION 6 :</u> Explain which parameter(s) you plan to change and why?</h4>
# <p><i>Type your answer here</i></p>

# %% [markdown]
# <p>The results are different but obviously when we identify mines we don't want to be wrong.</p>
#
# <h4> <u>QUESTION 7 :</u> Which one of the two methods is better? Is the accuracy acceptable? Why?</h4>
# <p><i>Type your answer here</i></p>
#
# <h4> <u>QUESTION 8 :</u> What can you conclude from the whole study</h4>
# <p><i>Type your answer here</i></p>
#
#
# <h4> <u>BONUS :</u> Copy/Paste the code to generate a pdf file containing the best tree and attach the file generated to your assignment when sending everything to me</h4>
